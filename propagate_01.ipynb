# %%
# %matplotlib widget

# %%
from astropy import units as u

from poliastro.bodies import Earth, Mars, Sun
from poliastro.twobody import Orbit

# %%
# Data from Curtis, example 4.3
r = [-6045, -3490, 2500] << u.km
v = [-3.457, 6.618, 2.533] << u.km / u.s

orb = Orbit.from_vectors(Earth, r, v)

# %%
orb
# Out:
# 7283 x 10293 km x 153.2 deg (GCRS) orbit around Earth (♁) at epoch J2000.000 (TT)

# %%
orb.plot()
# Out:
# [<matplotlib.lines.Line2D at 0x7f9cf51c9190>,
#  <matplotlib.lines.Line2D at 0x7f9cf50f00a0>]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
orb2 = orb.propagate(30 << u.min)

# %%
orb2.plot()
# Out:
# [<matplotlib.lines.Line2D at 0x7f9c15fa8b20>,
#  <matplotlib.lines.Line2D at 0x7f9c15fa8940>]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
